# %%
import pandas as pd
import requests
from pprint import pprint

API_KEY = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..l1mUnCY_HKDzmWXc0FDqMB8YCAoIYT3EtDrN0QiQASdEr4WWMAmASQ3kGGbQRyrcKKdkPhzjcxpiau9XTzoJig"
URL_TEMPLATE = "https://api.clashroyale.com/v1/players/{}/battlelog"

headers = {
    "Authorization": f"Bearer {API_KEY}"
}

def fetch_data(tag):
    url = URL_TEMPLATE.format(tag.replace("#", "%23"))  # Convert '#' to '%23' for URL encoding
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch data for tag {tag}. HTTP Status Code: {response.status_code}. Reason: {response.text}")
        return None

# %%
data = fetch_data("#PL2V2UUUP")

#   #PL2V2UUUP

# %%
print(len(data))
# Out:
# 17

# %%
pprint(data)
# Out:
# [{'arena': {'id': 54000013, 'name': 'Arena 16'},
#   'battleTime': '20231102T194041.000Z',
#   'deckSelection': 'collection',
#   'gameMode': {'id': 72000006, 'name': 'Ladder'},
#   'isHostedMatch': False,
#   'isLadderTournament': False,
#   'leagueNumber': 1,
#   'opponent': [{'cards': [{'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/0lIoYf3Y_plFTzo95zZL93JVxpfb3MMgFDDhgSDGU9A.png'},
#                            'id': 26000011,
#                            'level': 11,
#                            'maxLevel': 12,
#                            'name': 'Valkyrie',
#                            'starLevel': 1},
#                           {'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/MlArURKhn_zWAZY-Xj1qIRKLVKquarG25BXDjUQajNs.png'},
#                            'id': 26000004,
#                            'level': 9,
#                            'maxLevel': 9,
#                            'name': 'P.E.K.K.A',
# ...

# %%
for d in data: 
    pprint(d)
    print('\n')
# Out:
# {'arena': {'id': 54000013, 'name': 'Arena 16'},
#  'battleTime': '20231102T194041.000Z',
#  'deckSelection': 'collection',
#  'gameMode': {'id': 72000006, 'name': 'Ladder'},
#  'isHostedMatch': False,
#  'isLadderTournament': False,
#  'leagueNumber': 1,
#  'opponent': [{'cards': [{'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/0lIoYf3Y_plFTzo95zZL93JVxpfb3MMgFDDhgSDGU9A.png'},
#                           'id': 26000011,
#                           'level': 11,
#                           'maxLevel': 12,
#                           'name': 'Valkyrie',
#                           'starLevel': 1},
#                          {'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/MlArURKhn_zWAZY-Xj1qIRKLVKquarG25BXDjUQajNs.png'},
#                           'id': 26000004,
#                           'level': 9,
#                           'maxLevel': 9,
#                           'name': 'P.E.K.K.A',
#                           'starLevel': 2},
# ...

# %%
pprint(data[0]["opponent"])
# Out:
# [{'cards': [{'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/0lIoYf3Y_plFTzo95zZL93JVxpfb3MMgFDDhgSDGU9A.png'},
#              'id': 26000011,
#              'level': 11,
#              'maxLevel': 12,
#              'name': 'Valkyrie',
#              'starLevel': 1},
#             {'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/MlArURKhn_zWAZY-Xj1qIRKLVKquarG25BXDjUQajNs.png'},
#              'id': 26000004,
#              'level': 9,
#              'maxLevel': 9,
#              'name': 'P.E.K.K.A',
#              'starLevel': 2},
#             {'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/3En2cz0ISQAaMTHY3hj3rTveFN2kJYq-H4VxvdJNvCM.png'},
#              'id': 26000050,
#              'level': 3,
#              'maxLevel': 6,
#              'name': 'Royal Ghost'},
#             {'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/BmpK3bqEAviflqHCdxxnfm-_l3pRPJw3qxHkwS55nCY.png'},
# ...

# %%
pprint(data[0]["team"])
# Out:
# [{'cards': [{'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/cfwk1vzehVyHC-uloEIH6NOI0hOdofCutR5PyhIgO6w.png'},
#              'id': 26000007,
#              'level': 9,
#              'maxLevel': 9,
#              'name': 'Witch',
#              'starLevel': 2},
#             {'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/_iDwuDLexHPFZ_x4_a0eP-rxCS6vwWgTs6DLauwwoaY.png'},
#              'id': 28000011,
#              'level': 6,
#              'maxLevel': 6,
#              'name': 'The Log',
#              'starLevel': 1},
#             {'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/Flsoci-Y6y8ZFVi5uRFTmgkPnCmMyMVrU7YmmuPvSBo.png'},
#              'id': 28000001,
#              'level': 14,
#              'maxLevel': 14,
#              'name': 'Arrows',
#              'starLevel': 2},
# ...

# %%
if data is None:
    data = []

df = pd.DataFrame()
processed_tags = set()
used_tags = set()

# %%
print(data)
# Out:
# [{'type': 'PvP', 'battleTime': '20231102T194041.000Z', 'isLadderTournament': False, 'arena': {'id': 54000013, 'name': 'Arena 16'}, 'gameMode': {'id': 72000006, 'name': 'Ladder'}, 'deckSelection': 'collection', 'team': [{'tag': '#PL2V2UUUP', 'name': 'PapaOfXMen', 'startingTrophies': 5955, 'trophyChange': 27, 'crowns': 1, 'kingTowerHitPoints': 6408, 'princessTowersHitPoints': [3655, 4032], 'clan': {'tag': '#YCPRQ8L2', 'name': 'YellowStar', 'badgeId': 16000020}, 'cards': [{'name': 'Witch', 'id': 26000007, 'level': 9, 'starLevel': 2, 'maxLevel': 9, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/cfwk1vzehVyHC-uloEIH6NOI0hOdofCutR5PyhIgO6w.png'}}, {'name': 'The Log', 'id': 28000011, 'level': 6, 'starLevel': 1, 'maxLevel': 6, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/_iDwuDLexHPFZ_x4_a0eP-rxCS6vwWgTs6DLauwwoaY.png'}}, {'name': 'Arrows', 'id': 28000001, 'level': 14, 'starLevel': 2, 'maxLevel': 14, 'iconUrls': {'medium': 'https://api-assets.cla
# ...

# %%
while len(df) < 100000 and data:
    flattened_data = []

    for entry in data:
        if(entry["type"] == "PvP"):
            player = entry["team"][0]
            opponent = entry["opponent"][0]

            flattened_data.append({
                "type": entry["type"],
                "battleTime": entry["battleTime"],
                "arena_name": entry["arena"]["name"],
                "gameMode_name": entry["gameMode"]["name"],
                "deckSelection": entry["deckSelection"],
                "player_tag": player["tag"],
                "player_name": player["name"],
                "player_startingTrophies": player["startingTrophies"],
      #          "player_trophyChange": player["trophyChange"],
                "player_kingTowerHitPoints": player["kingTowerHitPoints"],
                "player_crowns": player["crowns"],
                #player card 1 info
                "player_cardone_name":player["cards"][0]["name"],
                "player_cardone_id":player["cards"][0]["id"],
                "player_cardone_level": player["cards"][0]["level"],
                #player card 2  info
                "player_cardtwo_name":player["cards"][1]["name"],      
                "player_cardtwo_id":player["cards"][1]["id"],
                "player_cardtwo_level": player["cards"][1]["level"], 
                #player card 3 info
                "player_cardthree_name":player["cards"][2]["name"],
                "player_cardthree_id":player["cards"][2]["id"],
                "player_cardthree_level": player["cards"][2]["level"], 
                #player card 4 info
                "player_cardfour_name":player["cards"][3]["name"],
                "player_cardfour_id":player["cards"][3]["id"],
                "player_cardfour_level": player["cards"][3]["level"], 
                #player card 5 info
                "player_cardfive_name":player["cards"][4]["name"],
                "player_cardfive_id":player["cards"][4]["id"],
                "player_cardfive_level": player["cards"][4]["level"], 
                #player card 6 info
                "player_cardsix_name":player["cards"][5]["name"],
                "player_cardsix_id":player["cards"][5]["id"],
                "player_cardsix_level": player["cards"][5]["level"], 
                #player card 7 info
                "player_cardseven_name":player["cards"][6]["name"],
                "player_cardseven_id":player["cards"][6]["id"],
                "player_cardseven_level": player["cards"][6]["level"], 
                #player card 8 info
                "player_cardeight_name":player["cards"][7]["name"],
                "player_cardeight_id":player["cards"][7]["id"],
                "player_cardeight_level": player["cards"][7]["level"], 
                #opponent information
                "opponent_tag": opponent["tag"],
                "opponent_name": opponent["name"],
                "opponent_startingTrophies": opponent["startingTrophies"],
      #          "opponent_trophyChange": opponent["trophyChange"],
                "opponent_kingTowerHitPoints": opponent["kingTowerHitPoints"],
                "opponent_crowns": opponent["crowns"],
                #opponent card 1 info
                "opponent_cardone_name":opponent["cards"][0]["name"],
                "opponent_cardone_id":opponent["cards"][0]["id"],
                "opponent_cardone_level": opponent["cards"][0]["level"],
                #opponent card 2  info
                "opponent_cardtwo_name":opponent["cards"][1]["name"],      
                "opponent_cardtwo_id":opponent["cards"][1]["id"],
                "opponent_cardtwo_level": opponent["cards"][1]["level"], 
                #opponent card 3 info
                "opponent_cardthree_name":opponent["cards"][2]["name"],
                "opponent_cardthree_id":opponent["cards"][2]["id"],
                "opponent_cardthree_level": opponent["cards"][2]["level"], 
                #opponent card 4 info
                "opponent_cardfour_name":opponent["cards"][3]["name"],
                "opponent_cardfour_id":opponent["cards"][3]["id"],
                "opponent_cardfour_level": opponent["cards"][3]["level"], 
                #opponent card 5 info
                "opponent_cardfive_name":opponent["cards"][4]["name"],
                "opponent_cardfive_id":opponent["cards"][4]["id"],
                "opponent_cardfive_level": opponent["cards"][4]["level"], 
                #opponent card 6 info
                "opponent_cardsix_name":opponent["cards"][5]["name"],
                "opponent_cardsix_id":opponent["cards"][5]["id"],
                "opponent_cardsix_level": opponent["cards"][5]["level"], 
                #opponent card 7 info
                "opponent_cardseven_name":opponent["cards"][6]["name"],
                "opponent_cardseven_id":opponent["cards"][6]["id"],
                "opponent_cardseven_level": opponent["cards"][6]["level"], 
                #opponent card 8 info
                "opponent_cardeight_name":opponent["cards"][7]["name"],
                "opponent_cardeight_id":opponent["cards"][7]["id"],
                "opponent_cardeight_level": opponent["cards"][7]["level"], 
            })

            processed_tags.add(opponent["tag"])

    # Append the new data to the DataFrame
    df = pd.concat([df, pd.DataFrame(flattened_data)], ignore_index=True)


    # Break the loop if we've reached the desired DataFrame size
    if len(df) >= 100000:
        break

    # Find new tags to process which haven't been processed yet
                 
    for row in processed_tags:
        if row not in used_tags:
            to_try = row
            used_tags.add(row)
            processed_tags.remove(row)
            break
    
    print(to_try)
    # Fetch data for the next unprocessed tag
    data = fetch_data(to_try)
    print(len(data))
    while len(data) == 0:
        for row in processed_tags:
            if row not in used_tags:
                to_try = row
                used_tags.add(row)
                processed_tags.remove(row)
                break
        data = fetch_data(to_try)
# Out:
# #2UVJYC2
# 33
# #LJQULJPYP
# 26
# #CG9LY0UC0
# 35
# #Q028LLC8
# 25
# #QCLGCVCJP
# 29
# #JL8JR8UC2
# 25
# #U9Y8UQ9GR
# 2
# #UQ2RUPY2J
# 25
# #9VRLJQ988
# 25
# #2R99GC8YU
# 27
# #CY9PPC0PJ
# 31
# #2LPQGCGRR
# 22
# #L92RV0GJU
# 30
# #2UCLVJ2PC
# 25
# #RY88VYV0J
# 25
# #8CV280GP2
# 26
# #J90PQJC0Y
# 28
# #YL9R0GCLU
# 25
# #YJJ9UQRPL
# 25
# #2GVQGRL2P
# 29
# #U992QQRJ9
# 6
# #UPRYY2VGY
# 2
# #VQ8YQCVRC
# 0
# #JLPP0UR8G
# 15
# #UY2YUJ00L
# 2
# #YJY2CCL2
# 26
# #29UC80PR
# 29
# #28298RURP
# 25
# #UCQ2J2J0V
# 25
# #2GV882VLG
# 25
# #RCUCYCGCG
# 35
# #Y892G2VL2
# 35
# #UPGVQYQYG
# 2
# #2890P99UG
# 21
# #2RV0PR8Q
# 21
# #J0V8CL2L8
# 25
# #PL08JRU8Y
# 25
# #8GR0YGLYQ
# 25
# #UR90YUJPJ
# 28
# #CUC88P0J9
# 25
# #PPQ0922JR
# 35
# #VC22L0CVU
# 2
# #RUL2GL289
# 25
# #VL2PLGU2V
# 35
# #YRLVCUJUJ
# 25
# #PC9GR98CR
# 25
# #UY2LUQVLG
# 2
# #Q290LYUVQ
# 32
# #PQC9802YP
# 35
# #2L8VYJVV8
# 25
# #UJ8VVJU22
# 32
# #U9PQRQCQ2
# 4
# #QUQCV2YYG
# 35
# #VJC2PL0U
# 31
# #P9V2CP8QQ
# 25
# #VJY2C9P8V
# 34
# ...

# %%
df
# Out:
#        type            battleTime arena_name    gameMode_name deckSelection  \
# 0       PvP  20231102T194041.000Z   Arena 16           Ladder    collection
# 1       PvP  20231101T234913.000Z   Arena 16           Ladder    collection
# 2       PvP  20231101T204654.000Z   Arena 16           Ladder    collection
# 3       PvP  20231031T234147.000Z   Arena 16           Ladder    collection
# 4       PvP  20231031T233753.000Z   Arena 16           Ladder    collection
# ...     ...                   ...        ...              ...           ...
# 99999   PvP  20231029T145906.000Z   Arena 17  Ladder_GoldRush    collection
# 100000  PvP  20231029T145551.000Z   Arena 17  Ladder_GoldRush    collection
# 100001  PvP  20231029T145206.000Z   Arena 17  Ladder_GoldRush    collection
# 100002  PvP  20231029T144819.000Z   Arena 17  Ladder_GoldRush    collection
# 100003  PvP  20231029T144455.000Z   Arena 17  Ladder_GoldRush    collection
#
# ...

# %%
print(len(df))
# Out:
# 100004

# %%
df.to_csv('class_royale_battlelog_dataset.csv', index=False)
print("Data saved to class_royale_battlelog_dataset.csv")
# Out:
# Data saved to class_royale_battlelog_dataset.csv
